# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# names = [
# "t",
# "Bond",
# "Proper Dih.",
# "Improper Dih.",
# "CMAP Dih.",
# "LJ (SR)",
# "Coulomb (SR)",
# "Potential",
# "Kinetic En.",
# "Total Energy"]

names = [
"t",
"Bond",
"U-B",
"Proper Dih.",
"Improper Dih.",
"CMAP Dih.",
"LJ-14",
"Coulomb-14",
"LJ (SR)",
"Coulomb (SR)",
"Coul. recip.",
"Potential",
"Kinetic En.",
"T-SOLU",
"T-SOLV"]

df = pd.read_csv("energy.xvg", skiprows=37, names=names, index_col=0, sep="  ")
# Out:
# /tmp/ipykernel_947427/3862185325.py:30: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("energy.xvg", skiprows=37, names=names, index_col=0, sep="  ")

# %%
df
# Out:
#                  Bond          U-B  Proper Dih.  Improper Dih.   CMAP Dih.  \
# t
# 0.0       1746.161621  4664.025391  5487.450195     289.977020 -391.003693
# 2.0       1906.565186  4755.009766  5562.322266     290.085541 -391.833923
# 4.0       1739.885132  4793.811523  5468.070312     312.489746 -394.961395
# 6.0       1610.870239  4605.860840  5443.548828     314.671112 -388.650726
# 8.0       1909.306885  4709.935547  5402.014160     296.813110 -343.759003
# ...               ...          ...          ...            ...         ...
# 299992.0  1711.755981  4848.206543  5345.149902     318.767242 -449.782196
# 299994.0  1659.904053  4683.634277  5197.520508     266.385559 -349.308716
# 299996.0  1888.495483  4802.510254  5279.933594     332.824310 -421.587738
# 299998.0  1727.236694  4507.175293  5186.873047     299.942078 -377.220032
# 300000.0  1646.404907  4571.335449  5239.489258     264.634674 -436.043213
#
# ...

# %%
df["Proper Dih."].plot()
# Out:
# <Axes: xlabel='t'>

# %%
df["CMAP Dih."].plot()
# Out:
# <Axes: xlabel='t'>

# %%
df["Coulomb-14"].plot()
# Out:
# <Axes: xlabel='t'>
