# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import mdtraj as mdt
from pathlib import Path
import matplotlib.pyplot as plt


import sys
sys.path.append("../analysis")
from rg import gmx_gyrate

# %%
xtc = "/data/gzappavigna/lmp_conf_builder/gmx/amber/step5_production_nojump.xtc"
pdb = "/data/gzappavigna/lmp_conf_builder/gmx/amber/step5_production_nojump.gro"

df = gmx_gyrate(xtc, pdb)
# Out:
#                       :-) GROMACS - gmx gyrate, 2024.2 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /data/gzappavigna/lmp_conf_builder/notebooks
# Command line:
#   gmx gyrate -f /data/gzappavigna/lmp_conf_builder/gmx/amber/step5_production_nojump.xtc -s /data/gzappavigna/lmp_conf_builder/gmx/amber/step5_production_nojump.gro -o /tmp/output.xvg
#
# Last frame     600000 time 300000.000
# Analyzed 600001 frames, last time 300000.000
#
# GROMACS reminds you: "If every study was groundbreaking, we'd end up with a bunch of holes in the ground and nothing built." (Anonymous)
# 27

# %%
traj = mdt.load(xtc, top=pdb)
rg = mdt.compute_rg(traj)
# Out:
# array([4.63188775, 4.63507985, 4.63139606, ..., 1.57649431, 1.58578897,
#        1.59143652])

# %%
rg.size
# Out:
# 600001

# %%
plt.plot(df.Rg.to_numpy())
plt.plot(rg)
